# %% [markdown]
# # Group Project: Arxiv Classifier
# Authors: Amir Yunus, Brandon Gay, Lee Oon Teng

# %%
from utils import load_data, split_data, save_model
from utils.architecture.deep_artificial_neural_network import DeepNeuralNetwork

# %% [markdown]
# # 06 - $M_2$: Deep Artificial Neural Network

# %% [markdown]
# ## 06.1 - Load the Data

# %%
filename = 'arxiv_lite'
df = load_data(f'../data/03_{filename}_engineered.bin')
df.shape
# Out:
#    title_emb_0  title_emb_1  title_emb_2  title_emb_3  title_emb_4  \
# 0    -0.336807     0.205785     0.174136    -0.176798    -0.305941
# 1    -0.193135     0.019145     0.063621    -0.222345    -0.535467
# 2    -0.307646     0.030398    -0.153520    -0.222931    -0.390395
# 3    -0.488771     0.154944     0.239354    -0.140129    -0.166575
# 4    -0.167175     0.223677    -0.232622    -0.130705    -0.447192
#
#    title_emb_5  title_emb_6  title_emb_7  title_emb_8  title_emb_9  ...  \
# 0     0.322368     0.129586     0.781946    -0.403417    -0.099831  ...
# 1     0.131508     0.126612     0.577781    -0.560718    -0.176797  ...
# 2     0.065084     0.222042     0.624599    -0.591892    -0.031597  ...
# 3     0.140046     0.091391     0.683050    -0.515521    -0.219456  ...
# 4     0.078025     0.250789     0.606733    -0.562184    -0.103338  ...
#
#    title_sentiment  summary_sentiment  comment_sentiment  authors_sentiment  \
# ...

# %% [markdown]
# ## 06.2 - Split the Data

# %%
X_train, X_val, X_test, y_train, y_val, y_test = split_data(df)
# Out:
# Train set: 737 samples
# Validation set: 312 samples
# Test set: 116 samples

# %% [markdown]
# ## 06.3 - Create the Model Object

# %%
m2_model = DeepNeuralNetwork(input_dim=X_train.shape[1])
# Out:
# Using device: mps

# %% [markdown]
# ## 06.4 - Train the Model

# %%
train_loss, val_loss = m2_model.fit(X_train, y_train, X_val, y_val)
# Out:
# Training: 100%|██████████| 100/100 [00:56<00:00,  1.77it/s, train_loss=1.6126, val_loss=1.7424, train_acc=75.17%, val_acc=69.55%]

# %% [markdown]
# ## 06.5 - Evaluate the Model

# %%
m2_model.predict(X_test, y_test)
# Out:
# Classification Report:
#                                             precision    recall  f1-score   support
#
#                           computer science       0.70      0.47      0.56        30
# electrical engineering and systems science       0.11      1.00      0.20         1
#                                mathematics       0.69      0.79      0.73        14
#                                    physics       0.83      0.83      0.83        52
#                       quantitative biology       0.46      0.60      0.52        10
#                       quantitative finance       0.83      0.71      0.77         7
#                                 statistics       0.00      0.00      0.00         2
#
#                                   accuracy                           0.69       116
#                                  macro avg       0.52      0.63      0.52       116
#                               weighted avg       0.73      0.69      0.70       116

# %% [markdown]
# ## 06.6 - Save the Model

# %%
save_model(m2_model, '../models/m2_deep_artificial_neural_network.bin')
# Out:
# Model saved successfully to ../models/m2_deep_artificial_neural_network.bin
