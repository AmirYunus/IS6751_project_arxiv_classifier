# %% [markdown]
# # Group Project: Arxiv Classifier
# Authors: Amir Yunus, Brandon Gay, Lee Oon Teng

# %%
from utils import load_data, save_data
import utils.data_preprocessing as process

# %% [markdown]
# # 01 - Data Preprocessing

# %% [markdown]
# ## 01.01 - Load the Data

# %%
filename = 'arxiv'
df = load_data(f'../data/{filename}.csv')
# Out:
#                                                title  \
# 0  Bayesian inversion for electromyography using ...
# 1  A reassessment of the kinematics of PV Cephei ...
# 2       A new minimal non-$σ$-scattered linear order
# 3  Proper phase imprinting method for a dark soli...
# 4  The impact of primordial supersonic flows on e...
#
#                                              summary  \
# 0  The reconstruction of the structure of biologi...
# 1  We present two Very Large Array observations o...
# 2  We will show it is consistent with $GCH$ that ...
# 3  It is common knowledge that a dark soliton can...
# 4  Tseliakhovich & Hirata recently discovered tha...
#
#                                              comment  \
# 0                                                NaN
# 1  15 pages, 2 figures; accepted for publication ...
# 2                                                NaN
# 3  5 pages, 2 figures, version accepted for publi...
# 4  Paulo maiora canamus - Accepted for publicatio...
#
#                                              authors     category  split
# 0  Anna Rörich, Tim A. Werthmann, Dominik Göddeke...  mathematics  train
# 1  L. Loinard, L. F. Rodriguez, L. Gomez, J. Cant...      physics  train
# 2                              Hossein Lamei Ramandi  mathematics  train
# 3                 Krzysztof Sacha, Dominique Delande      physics  train
# 4  Umberto Maio, Leon V. E. Koopmans, Benedetta C...      physics  train

# %% [markdown]
# ## 01.02 - Clean Categories

# %%
df = process.categories(df)
df.head()
# Out:
#                                                title  \
# 0  Bayesian inversion for electromyography using ...
# 1  A reassessment of the kinematics of PV Cephei ...
# 2       A new minimal non-$σ$-scattered linear order
# 3  Proper phase imprinting method for a dark soli...
# 4  The impact of primordial supersonic flows on e...
#
#                                              summary  \
# 0  The reconstruction of the structure of biologi...
# 1  We present two Very Large Array observations o...
# 2  We will show it is consistent with $GCH$ that ...
# 3  It is common knowledge that a dark soliton can...
# 4  Tseliakhovich & Hirata recently discovered tha...
#
#                                              comment  \
# 0                                                NaN
# 1  15 pages, 2 figures; accepted for publication ...
# 2                                                NaN
# 3  5 pages, 2 figures, version accepted for publi...
# 4  Paulo maiora canamus - Accepted for publicatio...
#
#                                              authors     category  split
# 0  Anna Rörich, Tim A. Werthmann, Dominik Göddeke...  mathematics  train
# 1  L. Loinard, L. F. Rodriguez, L. Gomez, J. Cant...      physics  train
# 2                              Hossein Lamei Ramandi  mathematics  train
# 3                 Krzysztof Sacha, Dominique Delande      physics  train
# 4  Umberto Maio, Leon V. E. Koopmans, Benedetta C...      physics  train

# %% [markdown]
# ## 01.03 - Remove Duplicates

# %%
df = process.duplicates(df)
df.head()
# Out:
#                                                title  \
# 0  Bayesian inversion for electromyography using ...
# 1  A reassessment of the kinematics of PV Cephei ...
# 2       A new minimal non-$σ$-scattered linear order
# 3  Proper phase imprinting method for a dark soli...
# 4  The impact of primordial supersonic flows on e...
#
#                                              summary  \
# 0  The reconstruction of the structure of biologi...
# 1  We present two Very Large Array observations o...
# 2  We will show it is consistent with $GCH$ that ...
# 3  It is common knowledge that a dark soliton can...
# 4  Tseliakhovich & Hirata recently discovered tha...
#
#                                              comment  \
# 0                                                NaN
# 1  15 pages, 2 figures; accepted for publication ...
# 2                                                NaN
# 3  5 pages, 2 figures, version accepted for publi...
# 4  Paulo maiora canamus - Accepted for publicatio...
#
#                                              authors     category  split
# 0  Anna Rörich, Tim A. Werthmann, Dominik Göddeke...  mathematics  train
# 1  L. Loinard, L. F. Rodriguez, L. Gomez, J. Cant...      physics  train
# 2                              Hossein Lamei Ramandi  mathematics  train
# 3                 Krzysztof Sacha, Dominique Delande      physics  train
# 4  Umberto Maio, Leon V. E. Koopmans, Benedetta C...      physics  train

# %% [markdown]
# ## 01.04 - Drop Null or NA Values

# %%
df = process.null(df)
df.head()
# Out:
#                                                title  \
# 0  A reassessment of the kinematics of PV Cephei ...
# 1  Proper phase imprinting method for a dark soli...
# 2  The impact of primordial supersonic flows on e...
# 3  Self-contracted curves in spaces with weak low...
# 4  High-harmonic generation in liquids with few-c...
#
#                                              summary  \
# 0  We present two Very Large Array observations o...
# 1  It is common knowledge that a dark soliton can...
# 2  Tseliakhovich & Hirata recently discovered tha...
# 3  We show that bounded self-contracted curves ar...
# 4  High-harmonic generation (HHG) in liquids is o...
#
#                                              comment  \
# 0  15 pages, 2 figures; accepted for publication ...
# 1  5 pages, 2 figures, version accepted for publi...
# 2  Paulo maiora canamus - Accepted for publicatio...
# 3  A goofy mistake in formulations of Theorem 2 a...
# 4                                 9 pages, 5 figures
#
#                                              authors     category  split
# 0  L. Loinard, L. F. Rodriguez, L. Gomez, J. Cant...      physics  train
# 1                 Krzysztof Sacha, Dominique Delande      physics  train
# 2  Umberto Maio, Leon V. E. Koopmans, Benedetta C...      physics  train
# 3    Nina Lebedeva, Shin-ichi Ohta, Vladimir Zolotov  mathematics  train
# 4  Angana Mondal, Benedikt Waser, Tadas Balciunas...      physics  train

# %% [markdown]
# ## 01.05 - Lowercase the Text Data

# %%
df = process.lowercase(df)
df.head()
# Out:
#                                                title  \
# 0  a reassessment of the kinematics of pv cephei ...
# 1  proper phase imprinting method for a dark soli...
# 2  the impact of primordial supersonic flows on e...
# 3  self-contracted curves in spaces with weak low...
# 4  high-harmonic generation in liquids with few-c...
#
#                                              summary  \
# 0  we present two very large array observations o...
# 1  it is common knowledge that a dark soliton can...
# 2  tseliakhovich & hirata recently discovered tha...
# 3  we show that bounded self-contracted curves ar...
# 4  high-harmonic generation (hhg) in liquids is o...
#
#                                              comment  \
# 0  15 pages, 2 figures; accepted for publication ...
# 1  5 pages, 2 figures, version accepted for publi...
# 2  paulo maiora canamus - accepted for publicatio...
# 3  a goofy mistake in formulations of theorem 2 a...
# 4                                 9 pages, 5 figures
#
#                                              authors     category  split
# 0  l. loinard, l. f. rodriguez, l. gomez, j. cant...      physics  train
# 1                 krzysztof sacha, dominique delande      physics  train
# 2  umberto maio, leon v. e. koopmans, benedetta c...      physics  train
# 3    nina lebedeva, shin-ichi ohta, vladimir zolotov  mathematics  train
# 4  angana mondal, benedikt waser, tadas balciunas...      physics  train

# %% [markdown]
# ## 01.06 - Remove Punctuation

# %%
df = process.punctuation(df)
df.head()
# Out:
#                                                title  \
# 0  a reassessment of the kinematics of pv cephei ...
# 1  proper phase imprinting method for a dark soli...
# 2  the impact of primordial supersonic flows on e...
# 3  selfcontracted curves in spaces with weak lowe...
# 4  highharmonic generation in liquids with fewcyc...
#
#                                              summary  \
# 0  we present two very large array observations o...
# 1  it is common knowledge that a dark soliton can...
# 2  tseliakhovich  hirata recently discovered that...
# 3  we show that bounded selfcontracted curves are...
# 4  highharmonic generation hhg in liquids is open...
#
#                                              comment  \
# 0  15 pages 2 figures accepted for publication in...
# 1  5 pages 2 figures version accepted for publica...
# 2  paulo maiora canamus  accepted for publication...
# 3  a goofy mistake in formulations of theorem 2 a...
# 4                                  9 pages 5 figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto a c ra...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.07 - Remove Numbers

# %%
df = process.numbers(df)
df.head()
# Out:
#                                                title  \
# 0  a reassessment of the kinematics of pv cephei ...
# 1  proper phase imprinting method for a dark soli...
# 2  the impact of primordial supersonic flows on e...
# 3  selfcontracted curves in spaces with weak lowe...
# 4  highharmonic generation in liquids with fewcyc...
#
#                                              summary  \
# 0  we present two very large array observations o...
# 1  it is common knowledge that a dark soliton can...
# 2  tseliakhovich  hirata recently discovered that...
# 3  we show that bounded selfcontracted curves are...
# 4  highharmonic generation hhg in liquids is open...
#
#                                              comment  \
# 0   pages  figures accepted for publication in re...
# 1   pages  figures version accepted for publicati...
# 2  paulo maiora canamus  accepted for publication...
# 3  a goofy mistake in formulations of theorem  an...
# 4                                     pages  figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto a c ra...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.08 - Remove Extra Whitespace

# %%
df = process.whitespace(df)
df.head()
# Out:
#                                                title  \
# 0  a reassessment of the kinematics of pv cephei ...
# 1  proper phase imprinting method for a dark soli...
# 2  the impact of primordial supersonic flows on e...
# 3  selfcontracted curves in spaces with weak lowe...
# 4  highharmonic generation in liquids with fewcyc...
#
#                                              summary  \
# 0  we present two very large array observations o...
# 1  it is common knowledge that a dark soliton can...
# 2  tseliakhovich hirata recently discovered that ...
# 3  we show that bounded selfcontracted curves are...
# 4  highharmonic generation hhg in liquids is open...
#
#                                              comment  \
# 0  pages figures accepted for publication in revm...
# 1  pages figures version accepted for publication...
# 2  paulo maiora canamus accepted for publication ...
# 3  a goofy mistake in formulations of theorem and...
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto a c ra...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.09 - Remove Stopwords

# %%
df = process.stopwords(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.10 - Handling Contractions

# %%
df = process.contractions(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.11 - Process Diacritics

# %%
df = process.diacritics(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.12 - Remove Special Characters

# %%
df = process.special_characters(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.13 - Handling Emojis and Emoticons

# %%
df = process.emojis(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.14 - Remove HTML Tags

# %%
df = process.html(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.15 - Enforce UTF-8 Encoding

# %%
df = process.utf8(df)
df.head()
# Out:
#                                                title  \
# 0  reassessment kinematics pv cephei based accura...
# 1  proper phase imprinting method dark soliton ex...
# 2  impact primordial supersonic flows early struc...
# 3  selfcontracted curves spaces weak lower curvat...
# 4  highharmonic generation liquids fewcycle pulse...
#
#                                              summary  \
# 0  present two large array observations premainse...
# 1  common knowledge dark soliton excited ultracol...
# 2  tseliakhovich hirata recently discovered highe...
# 3  show bounded selfcontracted curves rectifiable...
# 4  highharmonic generation hhg liquids opening ne...
#
#                                              comment  \
# 0        pages figures accepted publication revmexaa
# 1  pages figures version accepted publication phy...
# 2  paulo maiora canamus accepted publication mnra...
# 3           goofy mistake formulations theorem fixed
# 4                                      pages figures
#
#                                              authors     category  split
# 0  l loinard l f rodriguez l gomez j canto c raga...      physics  train
# 1                  krzysztof sacha dominique delande      physics  train
# 2    umberto maio leon v e koopmans benedetta ciardi      physics  train
# 3       nina lebedeva shinichi ohta vladimir zolotov  mathematics  train
# 4  angana mondal benedikt waser tadas balciunas o...      physics  train

# %% [markdown]
# ## 01.16 - Save the Processed Data

# %%
save_data(df, f'../data/01_{filename}_processed.bin')
# Out:
# Data saved successfully to ../data/01_arxiv_processed.bin
