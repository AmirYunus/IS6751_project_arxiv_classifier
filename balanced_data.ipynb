# %%
import pandas as pd

df = pd.read_csv('data/arxiv_large.csv')
df
# Out:
#                                                     title  \
# 0       Gamma-Ray Bursts as the Death Throes of Massiv...
# 1          Gravitational Lensing and the Variability of G
# 2                  The Ptolemaic Gamma-Ray Burst Universe
# 3       Expanding Photospheres of Type II Supernovae a...
# 4                  Radiation Transfer in Gamma-Ray Bursts
# ...                                                   ...
# 665795        A Truthful Owner-Assisted Scoring Mechanism
# 665796  Smooth Calibration, Leaky Forecasts, Finite Re...
# 665797                   Forecast Hedging and Calibration
# 665798  The Isotonic Mechanism for Exponential Family ...
# 665799                                  Statistical Games
#
#                                                   summary  \
# 0       It is proposed that gamma-ray bursts are creat...
# 1       The four observables associated with gravitati...
# 2       The BATSE experiment on GRO has demonstrated t...
# 3       We use the Expanding Photosphere Method to det...
# 4       We have calculated gamma-ray radiative transpo...
# ...                                                   ...
# 665795  Alice (owner) has knowledge of the underlying ...
# 665796  We propose to smooth out the calibration score...
# 665797  Calibration means that forecasts and average r...
# 665798  In 2023, the International Conference on Machi...
# 665799  This work contains the mathematical exploratio...
#
#                                                   comment  \
# 0                                                14 pages
# 1                    13 pages plus figures (not included)
# 2            10 pages (Replaced to provide omitted line.)
# 3                                                21 pages
# 4                                                24 pages
# ...                                                   ...
# 665795  A (significantly) extended version of arXiv: 2...
# 665796   http://www.ma.huji.ac.il/hart/publ.html#calib-eq
# 665797  http://www.ma.huji.ac.il/hart/publ.html#calib-int
# 665798                                                NaN
# 665799                              129 pages, 51 figures
#
#                                              authors          category  split
# 0       Ramesh Narayan, Bohdan Paczyński, Tsvi Piran           physics  train
# 1                      Lawrence Krauss, Martin White           physics   test
# 2                                         J. I. Katz           physics  train
# 3             B P Schmidt, R P Kirshner, R G Eastman           physics    val
# 4                         B. J. Carrigan, J. I. Katz           physics  train
# ...                                              ...               ...    ...
# 665795                                  Weijie J. Su  computer science   test
# 665796                   Dean P. Foster, Sergiu Hart         economics  train
# 665797                   Dean P. Foster, Sergiu Hart         economics  train
# 665798        Yuling Yan, Weijie J. Su, Jianqing Fan       mathematics  train
# 665799                                Jozsef Konczer       mathematics  train
#
# [665800 rows x 6 columns]

# %%
# Create a mapping dictionary for categories
category_mapping = {
    'mathematics': 'mathematics',
    'computer science': 'computer science', 
    'economics': 'economics',
    'statistics': 'statistics',
    'quantitative biology': 'quantitative biology',
    'quantitative finance': 'quantitative finance',
    'electrical engineering and systems science': 'electrical engineering and systems science'
}

# Apply mapping - anything not in the dictionary will be mapped to 'physics'
df['category'] = df['category'].map(lambda x: category_mapping.get(x, 'physics'))

# %%
# Count samples per category
category_counts = df['category'].value_counts()

# Find the category with minimum count
min_category = category_counts.idxmin()
min_count = category_counts.min()

print(f"Category with fewest samples: {min_category}")
print(f"Number of samples: {min_count}")
# Out:
# Category with fewest samples: economics
# Number of samples: 7787

# %%
# Create balanced dataset by taking first min_count samples from each category
balanced_df = pd.concat([
    df[df['category'] == cat].head(min_count) 
    for cat in df['category'].unique()
])

# Verify counts are equal
print("\nSamples per category in balanced dataset:")
print(balanced_df['category'].value_counts())
# Out:
# Samples per category in balanced dataset:
# category
# physics                                       7787
# computer science                              7787
# mathematics                                   7787
# quantitative biology                          7787
# quantitative finance                          7787
# electrical engineering and systems science    7787
# economics                                     7787
# statistics                                    7787
# Name: count, dtype: int64

# %%
# Save balanced dataset to CSV file
balanced_df.to_csv('./data/arxiv_balanced.csv', index=False)
